# %%
from dotenv import load_dotenv
load_dotenv("../tests/data/secret.env")
from os import environ as ENV

# %%
from sqlalchemy.engine import URL as DB_URL
uri = DB_URL.create(
            "postgresql+psycopg",
            username= ENV['NLDI_DB_USERNAME'],
            password= ENV['NLDI_DB_PASSWORD'],
            host= ENV['NLDI_DB_HOST'],
            port= int(ENV['NLDI_DB_PORT']),
            database= ENV['NLDI_DB_NAME'],
            )

# %%
from advanced_alchemy.service import SQLAlchemyAsyncRepositoryService
from advanced_alchemy.repository import SQLAlchemyAsyncRepository
from advanced_alchemy.extensions.flask import FlaskServiceMixin
from nldi.db.schemas.characteristics import DivergenceCharacteristics, LocalCharacteristics, TotalAccCharacteristics, CharacteristicMetaData

# %%
class CharacteristicsDataRepository(SQLAlchemyAsyncRepository[CharacteristicMetaData]):
    model_type = CharacteristicMetaData
    id_attribute = "characteristic_id"

class CharacteristicService(FlaskServiceMixin, SQLAlchemyAsyncRepositoryService[CharacteristicMetaData]):
    repository_type = CharacteristicsDataRepository

    async def totes(self) -> list[CharacteristicMetaData]:
        flist, c = await svc.list_and_count(
            CharacteristicMetaData.characteristic_id.like("TOT%")
        )
        print(f"Found {c} TOT characteristics")
        return flist

# %%
from sqlalchemy.ext.asyncio import AsyncSession
from sqlalchemy.ext.asyncio import create_async_engine

async_engine = create_async_engine(uri)

async with AsyncSession(bind=async_engine) as db_session:
    svc = CharacteristicService(session=db_session)
    flist = await svc.totes()
    for f in flist:
        _d = f.__dict__
        _d.pop("_sa_instance_state")
        print(_d)
# Out:
# Found 93 TOT characteristics
# {'characteristic_id': 'TOT_POPDENS10', 'units': 'persons per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728f746e4b0b13d3918aa1e', 'theme_url': 'unknown', 'dataset_label': 'Population density, persons per square kilometer per NHDPlus version 2 catchment', 'characteristic_description': 'Population density, persons per square kilometer per NHDPlus version 2 catchment', 'theme_label': 'Population', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_24', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Developed, High Intensity: Includes highly developed areas where people reside or work in high numbers. Examples include apartment complexes, row houses, and commercial/industrial. Impervious surfaces account for 80-100 percent of the total cover. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_BASIN_AREA', 'units': 'square kilometers', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'NHDPlusV2 flowline catchment area in square kilometers. -9999 denotes a flowline which has no catchment.', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HERBICIDE', 'units': 'kilogram per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57052ba4e4b0d4e2b756ab85', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Herbicide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'characteristic_description': 'Herbicide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_MIRAD_2012', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/573b78aee4b0dae0d5e3aeb7', 'theme_url': 'unknown', 'dataset_label': 'Percent of all land that?s irrigated agriculture in 2012 per NHDPlus version 2 catchment', 'characteristic_description': 'Percent of watershed in irrigated agriculture, from USGS 2012 250-m MODIS data', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_PPT7100_ANN', 'units': 'mm/year', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/573b70a7e4b0dae0d5e3ae85', 'theme_url': 'https://www.sciencebase.gov/catalog/item/566ef828e4b09cfe53ca76f7', 'dataset_label': '30 year (1971 - 2000) mean annual precipitation from 800m PRISM data per NHDPlus version 2 catchment', 'characteristic_description': 'Mean annual precip (mm) for the watershed, from 800m PRISM data.  30 years period of record 1971-2000. ', 'theme_label': 'Climate', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_PET', 'units': 'mm/year', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f96ed1e4b0a6037df06a2d', 'theme_url': 'https://www.sciencebase.gov/catalog/item/566ef828e4b09cfe53ca76f7', 'dataset_label': 'PRISM 30-year average Potential Evapotranspiration, 1971-2000 per NHDPlus version 2 catchment', 'characteristic_description': 'Mean-annual potential evapotranspiration (PET), estimated using the Hamon (1961) equation. ', 'theme_label': 'Climate', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ELEV_MAX', 'units': 'meters', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': "NHDPlusV2 flowline catchment's maximum elevation in meters. -9999 denotes a flowline which has no catchment.", 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_21', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Developed, Open Space: Includes areas with a mixture of some constructed materials, but mostly vegetation in the form of lawn grasses. Impervious surfaces account for less than 20 percent of total cover. These areas most commonly include large-lot single-family housing units, parks, golf courses, and vegetation planted in developed settings for recreation, erosion control, or aesthetic purposes. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ICEMASS', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57ab4009e4b05e859be1ad26', 'theme_url': 'unknown', 'dataset_label': 'Percent of NHDPlusV2 catchment that contains estuaries. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percent ice mass.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_BFI', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5669a8e3e4b08895842a1d4f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Base Flow Index (BFI), The BFI is a ratio of base flow to total streamflow, expressed as a percentage and ranging from 0 to 100. Base flow is the sustained, slowly varying component of streamflow, usually attributed to ground-water discharge to a stream.', 'characteristic_description': 'Base Flow Index (BFI), The BFI is a ratio of base flow to total streamflow, expressed as a percentage and ranging from 0 to 100. Base flow is the sustained, slowly varying component of streamflow, usually attributed to ground-water discharge to a stream.', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_INSECTICIDE', 'units': 'kilogram per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57052c47e4b0d4e2b756ac39', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Insecticide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'characteristic_description': 'Insecticide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGVAR', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group VAR soil. -9999 denotes NODATA, usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_OLSON_PERM', 'units': '10^-6 m/s', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5703e35be4b0328dcb825562', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated mean lithological compressive strength, measured as uniaxial compressive strength (in megaPascals, MPa) of surface or near surface geology per NHDPlusV2 catchment.', 'characteristic_description': 'Rock hydraulic conductivity (10^-6 m/s).', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_22', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Developed, Low Intensity: Includes areas with a mixture of constructed materials and vegetation. Impervious surfaces account for 20-49 percent of total cover. These areas most commonly include single-family housing units. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGA', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group A soil. -9999 denotes NODATA, usually water. Hydrologic group A soils have high infiltration rates. Soils are deep and well drained and, typically, have high sand and gravel content.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_WBM_AET', 'units': 'Producer defined', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5783e16ae4b0ac0b97f54285', 'theme_url': 'unknown', 'dataset_label': 'Annual reach catchment value of temperature (TAV) from the water balance model averaged over the years 2000-2014, detrended to 2012. -9999 denotes NODATA.', 'characteristic_description': 'Annual reach catchment value of actual evapotranspiration (AET) from the water balance model averaged over the years 2000-2014. -9999 denotes NODATA.', 'theme_label': 'Climate and Water Balance', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_TOTAL_ROAD_DENS', 'units': 'kilometer of roads per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'Density of all road types per NHDPlusV2 catchment. Density is defined as the length of road divided by the catchment area.', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_41', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Deciduous Forest: Areas dominated by trees generally greater than 5 meters tall, and greater than 20 percent of total vegetation cover. More than 75 percent of the tree species shed foliage simultaneously in response to seasonal change. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_SWAMPMARSH', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57ab4009e4b05e859be1ad26', 'theme_url': 'unknown', 'dataset_label': 'Percent of NHDPlusV2 catchment that contains estuaries. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percent swamps or marshes.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_200', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Semiconsolidated sand aquifers.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_STREAM_LENGTH', 'units': 'kilometers', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': "NHDPlus version 2 flowline's length in kilometers taken directly from NHDPlusv2's NHDflowline shapefile's item, LENGTHKM. -9999 denotes a catchment has no flowline.", 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_RH', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57054a24e4b0d4e2b756d0e7', 'theme_url': 'https://www.sciencebase.gov/catalog/item/566ef828e4b09cfe53ca76f7', 'dataset_label': 'PRISM 30-year average  (1961-1990) relative humidity (percent) per NHDPlus version 2 catchment. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Watershed average relative humidity (percent), from 2km PRISM, derived from 30 years of record (1961-1990).', 'theme_label': 'Climate', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_CONNECTOR', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'flowlines coded as connectors', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_RUN7100', 'units': 'millimeters per year', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/578f8ad8e4b0ad6235cf6e43', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Estimated 30-year (1971-2000) average annual runoff in mm/year per NHDPlus version 2 catchment. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Estimated 30-year (1971-2000) average annual runoff in millimeters per year', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_EWT', 'units': 'meters', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f97456e4b0a6037df06b50', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Average depth to water table relative to land surface per NHDPlus version 2 catchment', 'characteristic_description': 'Average depth to water table relatice to the land surface(meters)', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_400', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Carbonate-rock aquifers.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_STRM_DENS', 'units': 'km -1', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'stream density of catchment reach', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_81', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Pasture/Hay: Areas of grasses, legumes, or grass-legume mixtures planted for livestock grazing or the production of seed or hay crops, typically on a perennial cycle. Pasture/hay vegetation accounts for greater than 20 percent of total vegetation. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_23', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Developed, Medium Intensity: Includes areas with a mixture of constructed materials and vegetation. Impervious surfaces account for 50-79 percent of the total cover. These areas most commonly include single-family housing units. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NEMATICIDE', 'units': 'kilogram per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/570535aae4b0d4e2b756b78c', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Nematicide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'characteristic_description': 'Nematicide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_43', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Mixed Forest: Areas dominated by trees generally greater than 5 meters tall, and greater than 20 percent of total vegetation cover. Neither deciduous nor evergreen species are greater than 75 percent of total tree cover. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_600', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Igneous and metamorphic-rock aquifers.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_31', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Barren Land (Rock/Sand/Clay): Barren areas of bedrock, desert pavement, scarps, talus, slides, volcanic material, glacial debris, sand dunes, strip mines, gravel pits, and other accumulations of earthen material. Generally, vegetation accounts for less than 15 percent of total cover. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGD', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group D soil. -9999 denotes NODATA, usually water. Hydrologic group D soils have very slow infiltration rates. Soils are clayey, have a high water table, or have a shallow impervious layer.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_12', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Perennial Ice/Snow: All areas characterized by a perennial cover of ice and/or snow, generally greater than 25 percent of total cover. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_DITCHES92', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57067257e4b03f95a075ab0c', 'theme_url': 'unknown', 'dataset_label': 'Estimated percent area of field ditches on agricultural land for the year 1992 per NHDPlus version 2 catchment. -9999 denotes the source data does not underly the NHDPlusV2 catchments and therefore is NODATA.', 'characteristic_description': 'Percent of watershed subjected to ditches for the year 1992', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ELEV_MIN', 'units': 'meters', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': "NHDPlusV2 flowline catchment's minimum elevation in meters. -9999 denotes a flowline which has no catchment.", 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_POPDENS00', 'units': 'persons per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728f532e4b0b13d3918aa0a', 'theme_url': 'unknown', 'dataset_label': 'Population density, persons per square kilometer from 2000 Census block level data per NHDPlus version 2 catchment', 'characteristic_description': 'Population density, persons per square kilometer from 2000 Census block level data per NHDPlus version 2 catchment', 'theme_label': 'Population', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_RDX', 'units': 'number of road and stream crossings', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'number of road and stream intersections', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_FRESHWATER_WD', 'units': 'megaliters per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57c9dc05e4b0f2f0cec192f2', 'theme_url': 'unknown', 'dataset_label': 'Million gallons per year per square kilometer per NHDPlus version 2.1 catchment for January 2016. -9999 denotes NODATA.', 'characteristic_description': 'freshwater withdrawals from 1995-2000 county-level estimates', 'theme_label': 'Water Use', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_42', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Evergreen Forest: Areas dominated by trees generally greater than 5 meters tall, and greater than 20 percent of total vegetation cover. More than 75 percent of the trees maintain their leaves all year. Canopy is never without green foliage. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_CANALDITCH', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'flowlines coded as canals or ditches', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_TAV7100_ANN', 'units': 'degrees C', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57054bf2e4b0d4e2b756d364', 'theme_url': 'https://www.sciencebase.gov/catalog/item/566ef828e4b09cfe53ca76f7', 'dataset_label': '30 year (1971 - 2000) mean annual temperature (Celsius) per NHDPlus version 2 catchment. -9999 denotes NODATA.', 'characteristic_description': 'Watershed average of monthly air temperature (degrees C) from 800m PRISM, derived from 30 years of record (1971-2000).', 'theme_label': 'Climate', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_CONTACT', 'units': 'days', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f96fc5e4b0a6037df06b12', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Contact time, the length of time it takes for water to drain along subsurface flow paths to the stream, per NHDPlus version 2 catchment.', 'characteristic_description': 'Subsurface flow contact time index. The subsurface contact time index estimates the number of days that infiltrated water resides in the saturated subsurface zone of the basin before discharging into the stream.', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ET', 'units': 'mm/year', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5705491be4b0d4e2b756cf8a', 'theme_url': 'https://www.sciencebase.gov/catalog/item/566ef828e4b09cfe53ca76f7', 'dataset_label': 'Mean-annual evapotranspiration, estimated by Senay and others (2013) per NHDPlus version 2 catchment.', 'characteristic_description': 'Mean-annual actual evapotranspiration (ET), estimated using regression equation of Sanford and Selnick (2013)', 'theme_label': 'Climate', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_LAKEPOND', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57ab4009e4b05e859be1ad26', 'theme_url': 'unknown', 'dataset_label': 'Percent of NHDPlusV2 catchment that contains estuaries. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percent lakes or ponds.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_PLAYA', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57ab4009e4b05e859be1ad26', 'theme_url': 'unknown', 'dataset_label': 'Percent of NHDPlusV2 catchment that contains estuaries. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percent playas.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ESTUARY', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57ab4009e4b05e859be1ad26', 'theme_url': 'unknown', 'dataset_label': 'Percent of NHDPlusV2 catchment that contains estuaries. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percent estuaries.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NPDES_MAJ_DENS', 'units': 'sites per 100 square kilometers', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57c9d89ce4b0f2f0cec192da', 'theme_url': 'unknown', 'dataset_label': 'Density of major NPDES sites per NHDPlus version 2 catchment.', 'characteristic_description': 'Density of major NPDES sites', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_POPDENS90', 'units': 'persons per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728f609e4b0b13d3918aa0e', 'theme_url': 'unknown', 'dataset_label': 'Population density, persons per square kilometer per NHDPlus version 2 catchment', 'characteristic_description': 'Population density, persons per square kilometer per NHDPlus version 2 catchment', 'theme_label': 'Population', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_PIPELINE', 'units': 'percentage', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'Percentage of all flowline reach lengths per NHDPlusV2 catchment that is a pipe line. Pipelines are specifically man-made structures of steel, concrete, or polymers that direct surface water flows from one area to another.', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_71', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Grassland/Herbaceous: Areas dominated by graminoid or herbaceous vegetation, generally greater than 80 percent of total vegetation. These areas are not subject to intensive management such as tilling, but can be utilized for grazing. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ARTIFICIAL', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'flowlines coded as Artificial paths', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_SATOF', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f97acbe4b0a6037df06b6a', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Mean saturation overland flow as a percent of streamflow per NHDPlus version 2 catchment. -9999 denotes NODATA or flowline has no catchment. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percentage of Dunne overland flow as a percent', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_11', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Open Water: All areas of open water, generally with less than 25 percent cover of vegetation or soil. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_82', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Cultivated Crops: Areas used for the production of annual crops, such as corn, soybeans, vegetables, tobacco, and cotton, and also perennial woody crops such as orchards and vineyards. Crop vegetation accounts for greater than 20 percent of total vegetation. This class also includes all land being actively tilled. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_RESERVOIR', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57ab4009e4b05e859be1ad26', 'theme_url': 'unknown', 'dataset_label': 'Percent of NHDPlusV2 catchment that contains estuaries. -9999 denotes flowline reach has no catchment.', 'characteristic_description': 'Percent reservoirs.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_RECHG', 'units': 'mm/yr', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f97577e4b0a6037df06b5a', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Estimated 30 year (1951-1980) mean annual natural groundwater recharge per NHDPlus version 2 catchment. -9999 denotes source data does not cover catchment.', 'characteristic_description': 'Mean annual natural ground-water recharge in millimeters per year', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGCD', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group CD soil. -9999 denotes NODATA, usually water. Hydrologic group CD soils have group C characteristics (slow infiltration rates) when artificially drained and have group D characteristics (very slow infiltration rates) when not drained.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NPDES_MAJ', 'units': 'count', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57c9d89ce4b0f2f0cec192da', 'theme_url': 'unknown', 'dataset_label': 'Density of major NPDES sites per NHDPlus version 2 catchment.', 'characteristic_description': 'Number of major NPDES sites', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_STREAMRIVER', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': 'flowlines coded as Streams or Rivers', 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGB', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group B soil. -9999 denotes NODATA, usually water. Hydrologic group B soils have moderate infiltration rates. Soils are moderately deep, moderately well drained, and moderately coarse in texture.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_52', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Shrub/Scrub: Areas dominated by shrubs less than 5 meters tall. Shrub canopy is typically greater than 20 percent of total vegetation. This class includes true shrubs, young trees in an early successional stage or trees stunted from environmental conditions. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGBD', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group BD soil. -9999 denotes NODATA, usually water. Hydrologic group BD soils have group B characteristics (moderate infiltration rates) when artificially drained and have group D characteristics (very slow infiltration rates) when not drained.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_FUNGICIDE', 'units': 'kilogram per square kilometer', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56fd610fe4b022712b81bf9f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Fungicide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'characteristic_description': 'Fungicide use on agricultural land in kilograms per square kilometer, 2009 per NHDPlus version 2 catchment', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_MAJOR2013', 'units': 'count', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/58c301f2e4b0f37a93ed915a', 'theme_url': 'unknown', 'dataset_label': 'Number of major dams built on or before YYYY in each NHDPlusV2 catchment. Major dams defined as being >= 50 feet in height (15m) or having storage >= 5,000 acre feet, where YYYY is the last year for the decade of record (for example 1960 spans 1951 - 1960). The exceptions are 1930 and 2013 (1930 and before and 2010 to 2010 respectively).', 'characteristic_description': 'Number of major dams built on or before YYYY in each NHDPlusV2 catchment. Major dams defined as being >= 50 feet in height (15m) or having storage >= 5,000 acre feet', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_300', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Sandstone aquifers.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_MIRAD_2007', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/573b7850e4b0dae0d5e3aeb0', 'theme_url': 'unknown', 'dataset_label': 'Percent of all land that?s irrigated agriculture in 2007 per NHDPlus version 2 catchment', 'characteristic_description': 'Percent of watershed in irrigated agriculture, from USGS 2007 250-m MODIS data', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_90', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Woody Wetlands: Areas where forest or shrubland vegetation accounts for greater than 20 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_500', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Sandstone and carbonate-rock aquifers.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ELEV_MEAN', 'units': 'meters', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': "NHDPlusV2 flowline catchment's mean elevation in meters. -9999 denotes a flowline which has no catchment.", 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_P97', 'units': 'kg/sqkm', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57053749e4b0d4e2b756b969', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Mean rate of phosphorous from fertilizer and manure applied on agricultural land in 1997 per NHDPlus version 2 catchment', 'characteristic_description': 'Estimate of phosphorous from fertilizer and manure, from Census of Ag 1997 and AAPFCO', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NDAMS2013', 'units': 'count', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/58c301f2e4b0f37a93ed915a', 'theme_url': 'unknown', 'dataset_label': 'Number of major dams built on or before YYYY in each NHDPlusV2 catchment. Major dams defined as being >= 50 feet in height (15m) or having storage >= 5,000 acre feet, where YYYY is the last year for the decade of record (for example 1960 spans 1951 - 1960). The exceptions are 1930 and 2013 (1930 and before and 2010 to 2010 respectively).', 'characteristic_description': 'Number of dams built on or before YYYY ,', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_WBM_PET', 'units': 'Producer defined', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5783e16ae4b0ac0b97f54285', 'theme_url': 'unknown', 'dataset_label': 'Annual reach catchment value of temperature (TAV) from the water balance model averaged over the years 2000-2014, detrended to 2012. -9999 denotes NODATA.', 'characteristic_description': 'Annual reach catchment value of potential evapotranspiration (PET) from the water balance model averaged over the years 2000-2014. -9999 denotes NODATA.', 'theme_label': 'Climate and Water Balance', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_N97', 'units': 'kg/sqkm', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57053205e4b0d4e2b756b353', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Mean rate of nitrogen from fertilizer and manure applied on agricultural land in 1997 per NHDPlus version 2 catchment', 'characteristic_description': 'Estimate of nitrogen from fertilizer and manure, from Census of Ag 1997 and AAPFCO', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_PEST219', 'units': 'kg/sqkm', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57bf5e62e4b0f2f0ceb75b79', 'theme_url': 'https://www.sciencebase.gov/catalog/item/56fd600fe4b022712b81bf9a', 'dataset_label': 'Estimate of agricultural pesticide application (219 types), kg/sq km, from Census of Ag 1997, based on county-wide sales and percent agricultural land cover in watershed', 'characteristic_description': 'Estimate of agricultural pesticide application (219 types), kg/sq km, from Census of Ag 1997, based on county-wide sales and percent agricultural land cover in watershed', 'theme_label': 'Chemical', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NID_STORAGE2013', 'units': 'acre-feet', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/58c301f2e4b0f37a93ed915a', 'theme_url': 'unknown', 'dataset_label': 'Number of major dams built on or before YYYY in each NHDPlusV2 catchment. Major dams defined as being >= 50 feet in height (15m) or having storage >= 5,000 acre feet, where YYYY is the last year for the decade of record (for example 1960 spans 1951 - 1960). The exceptions are 1930 and 2013 (1930 and before and 2010 to 2010 respectively).', 'characteristic_description': 'The maximum dam storage (in acre-feet) defined as the total storage space in all reservoirs in a flowline catchment below the maximum attainable water surface elevation, including any surcharge storage, of dams built on or before YYYY. Value is based on dams built on or before YYYY', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_STREAM_SLOPE', 'units': 'percent rise', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': "NHDPlus version 2 flowline's average slope in percent. -9999 denotes a flow line with no change in elevation or unable to determine or flowline has no catchment.", 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGBC', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group BC soil. -9999 denotes NODATA, usually water. Hydrologic group BC soils have group B characteristics (moderate infiltration rates) when artificially drained and have group C characteristics (slow infiltration rates) when not drained.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_999', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Other rocks.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_TWI', 'units': 'ln(m)', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f97be4e4b0a6037df06b70', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'average topgraphic wetness index per NHDPlus version 2 catchment', 'characteristic_description': 'Topographic wetness index, ln(a/S); where ln is the natural log, a is the upslope area per unit contour length and S is the slope at that point.  See http://ks.water.usgs.gov/Kansas/pubs/reports/wrir.99-4242.html and Wolock and McCabe, 1995 for more detail', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGAD', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group AD soil. -9999 denotes NODATA, usually water. Hydrologic group AD soils have group A characteristics (high infiltration rates) when artificially drained and have group D characteristics (very slow infiltration rates) when not drained.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NLCD01_95', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5761b67de4b04f417c2d30ae', 'theme_url': 'unknown', 'dataset_label': '2011 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'characteristic_description': '2001 land-use and land-cover type Emergent Herbaceous Wetlands: Areas where perennial herbaceous vegetation accounts for greater than 80 percent of vegetative cover and the soil or substrate is periodically saturated with or covered with water. -9999 denotes NODATA.', 'theme_label': 'Land Cover', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGAC', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group AC soil. -9999 denotes NODATA, usually water. Hydrologic group AC soils have group A characteristics (high infiltration rates) when artificially drained and have group C characteristics (slow infiltration rates) when not drained.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_TILES92', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57067469e4b03f95a075ad3e', 'theme_url': 'unknown', 'dataset_label': 'Estimated percent area of subsurface drainage for the year 1992 per NHDPlus version 2 catchment. -9999 denotes NODATA.', 'characteristic_description': 'Percent of watershed subjected to tile drains for the year 1992', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_MIRAD_2002', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/573b77afe4b0dae0d5e3aea6', 'theme_url': 'unknown', 'dataset_label': 'Percent of all land that?s irrigated agriculture in 2002 per NHDPlus version 2 catchment', 'characteristic_description': 'Percent of watershed in irrigated agriculture, from USGS 2002 250-m MODIS data', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_NORM_STORAGE2013', 'units': 'acre-feet', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/58c301f2e4b0f37a93ed915a', 'theme_url': 'unknown', 'dataset_label': 'Number of major dams built on or before YYYY in each NHDPlusV2 catchment. Major dams defined as being >= 50 feet in height (15m) or having storage >= 5,000 acre feet, where YYYY is the last year for the decade of record (for example 1960 spans 1951 - 1960). The exceptions are 1930 and 2013 (1930 and before and 2010 to 2010 respectively).', 'characteristic_description': 'The normal dam storage (in acre-feet) defined as the total storage space in all reservoirs in a flowline catchment that is below the normal retention level, including dead and inactive storage and excluding any flood control or surcharge storage. Value is based on dams built on or before YYYY', 'theme_label': 'Hydrologic Modifications', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_HGC', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/5728d93be4b0b13d3918a99f', 'theme_url': 'https://www.sciencebase.gov/catalog/item/568d6554e4b0e7a44bc207f7', 'dataset_label': 'Percentage of soils found in an NHDPlus version 2 catchment that contains Hydrologic Group VAR soil. -9999 denotes NODATA,  usually water. Hydrologic group VAR soils have variable drainage characteristics.', 'characteristic_description': 'Percentage of Hydrologic Group C soil. -9999 denotes NODATA, usually water. Hydrologic group C soils have slow soil infiltration rates. The soil profiles include layers impeding downward movement of water and, typically, have moderately fine or fine texture.', 'theme_label': 'Soils', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_WB5100_ANN', 'units': 'millimeters per year', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56fd5bd0e4b0c07cbfa40473', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': "Average annual runoff (mm) from McCabe and Wolock's Runoff Model 1951-2000 per NHDPlus version 2 catchment", 'characteristic_description': "Average annual runoff (mm) from McCabe and Wolock's Runoff Model 1951-2000 per NHDPlus version 2 catchment", 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_ROCKTYPE_100', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/582b3855e4b0c253be05fc81', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5703c816e4b0328dcb82295a', 'dataset_label': 'Estimated percent of catchment that is underlain by the Principal Aquifer, Piedmont and Blue Ridge crystalline-rock aquifers.', 'characteristic_description': 'Estimated percent of catchment that is underlain by the Principal Aquifer rock type, Unconsolidated sand and gravel aquifers.', 'theme_label': 'Geology', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_IEOF', 'units': 'percent', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/56f974e2e4b0a6037df06b55', 'theme_url': 'https://www.sciencebase.gov/catalog/item/5669a8a4e4b08895842a1d4c', 'dataset_label': 'Mean infiltration-excess overland flow as a percent of streamflow per NHDPlus version 2 catchment', 'characteristic_description': 'Percentage of Horton overland flow as a percent', 'theme_label': 'Hydrologic', 'characteristic_type': 'totRoute_name'}
# {'characteristic_id': 'TOT_BASIN_SLOPE', 'units': 'percent rise', 'dataset_url': 'https://www.sciencebase.gov/catalog/item/57976a0ce4b021cadec97890', 'theme_url': 'unknown', 'dataset_label': 'Flowline catchment stream density calculated as stream length (meters) divided by catchment(s) area (square kilometers).', 'characteristic_description': "NHDPlusV2 flowline catchment's average slope in percent. -9999 denotes a flowline which has no catchment.", 'theme_label': 'Topographic', 'characteristic_type': 'totRoute_name'}

# %% [raw]
# SELECT tac.comid, tac.characteristic_id, mdata.characteristic_description
# FROM characteristic_data.total_accumulated_characteristics as tac
# join characteristic_data.characteristic_metadata as mdata on  mdata.characteristic_id = tac.characteristic_id
# where tac.comid = 13293396
# limit 20
